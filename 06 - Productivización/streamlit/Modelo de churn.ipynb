# %%
import pandas as pd

# %%
df_churn = pd.read_csv('telco_churn.csv')
df_churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df_churn.shape
# Out:
# (7043, 21)

# %%
df_churn.Churn.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# Implementa un modelo de churn utilizando las siguientes variables de entrada:
# * `gender`
# * `PaymentMethod`
# * `MonthlyCharges`
# * `tenure`

# %%
df_churn = df_churn[['gender','PaymentMethod','MonthlyCharges','tenure','Churn']].copy()
df_churn
# Out:
#       gender              PaymentMethod  MonthlyCharges  tenure Churn
# 0     Female           Electronic check           29.85       1    No
# 1       Male               Mailed check           56.95      34    No
# 2       Male               Mailed check           53.85       2   Yes
# 3       Male  Bank transfer (automatic)           42.30      45    No
# 4     Female           Electronic check           70.70       2   Yes
# ...      ...                        ...             ...     ...   ...
# 7038    Male               Mailed check           84.80      24    No
# 7039  Female    Credit card (automatic)          103.20      72    No
# 7040  Female           Electronic check           29.60      11    No
# 7041    Male               Mailed check           74.40       4   Yes
# 7042    Male  Bank transfer (automatic)          105.65      66    No
#
# [7043 rows x 5 columns]

# %%
df = df_churn.copy()
df.fillna(0,inplace=True)

# %%
# Codificar las variables
encode = ['gender','PaymentMethod']

for col in encode:
    dummy = pd.get_dummies(df[col],prefix=col)
    df = pd.concat([df,dummy],axis=1)
    del df[col]

# %%
df
# Out:
#       MonthlyCharges  tenure Churn  gender_Female  gender_Male  \
# 0              29.85       1    No              1            0
# 1              56.95      34    No              0            1
# 2              53.85       2   Yes              0            1
# 3              42.30      45    No              0            1
# 4              70.70       2   Yes              1            0
# ...              ...     ...   ...            ...          ...
# 7038           84.80      24    No              0            1
# 7039          103.20      72    No              1            0
# 7040           29.60      11    No              1            0
# 7041           74.40       4   Yes              0            1
# 7042          105.65      66    No              0            1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 0                                           0
# 1                                           0
# 2                                           0
# ...

# %%
import numpy as np
df['Churn'] = np.where(df['Churn']=='Yes',1,0)

# %%
df
# Out:
#       MonthlyCharges  tenure  Churn  gender_Female  gender_Male  \
# 0              29.85       1      0              1            0
# 1              56.95      34      0              0            1
# 2              53.85       2      1              0            1
# 3              42.30      45      0              0            1
# 4              70.70       2      1              1            0
# ...              ...     ...    ...            ...          ...
# 7038           84.80      24      0              0            1
# 7039          103.20      72      0              1            0
# 7040           29.60      11      0              1            0
# 7041           74.40       4      1              0            1
# 7042          105.65      66      0              0            1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 0                                           0
# 1                                           0
# 2                                           0
# ...

# %%
X = df.drop('Churn',axis=1)
y = df['Churn']

# %%
# División train-test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
X_train.shape
# Out:
# (5634, 8)

# %%
X_test.shape
# Out:
# (1409, 8)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict = clf.predict(X_test)

# %%
y_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test,y_predict))
print(confusion_matrix(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83      1033
#            1       0.53      0.43      0.47       376
#
#     accuracy                           0.75      1409
#    macro avg       0.67      0.65      0.65      1409
# weighted avg       0.73      0.75      0.74      1409
#
# [[888 145]
#  [214 162]]

# %%
import pickle
pickle.dump(clf, open('churn_clf.pkl', 'wb'))

# %% [markdown]
# ### Para publicar la app en la web

# %% [markdown]
# 1. To start, log into your Github account if you have one. If you don’t, create a Github account first.
#
# 2. On the left-hand panel, click the green New button next to where it says Repositories.
#
# 3. Create a name for your repository. {yourname}-churn-app should be fine.
#
# 4. Click on the link Upload an Existing File and click on Choose Files.
#
# 5. Add all files in codecrew_churn_app-main to the repo and click Commit.
#
# 6. Go to Heroku.com and create an account.
#
# 7. Log in to your account.
#
# 8. Click on the New button on the upper right and click Create New App.
#
# 9. You can name the app whatever you’d like. I named my app as follows: {name}-churn-app. I.e.: sadrach-churn-app and click Create App.
#
# 10. In the deployment method, click GitHub
#
# 11. Connect to your GitHub repo.
#
# 12. Log in and copy and paste the name of your repo. Click Search and Connect.
#
# 13. Scroll down to Manual Deploy and click Deploy Branch.
#
# 14. Wait a few minutes, and your app should be live!
