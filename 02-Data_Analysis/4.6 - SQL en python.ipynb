# %% [markdown]
# # 4.6 - SQL en python
#
# **Primero cargar datos...**

# %%
# cargar datos

import pandas as pd

df=pd.read_csv('../data/shoes.csv')

df.head()
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3  AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4  AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
#
#          brand                                         categories  \
# 0  Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
#
#   primaryCategories                          colors                 dimension  \
# ...

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   10000 non-null  object
#  1   dateAdded            10000 non-null  object
#  2   dateUpdated          10000 non-null  object
#  3   asins                3 non-null      object
#  4   brand                10000 non-null  object
#  5   categories           10000 non-null  object
#  6   primaryCategories    10000 non-null  object
#  7   colors               2631 non-null   object
#  8   dimension            117 non-null    object
#  9   ean                  671 non-null    float64
#  10  imageURLs            10000 non-null  object
#  11  keys                 10000 non-null  object
#  12  manufacturer         527 non-null    object
#  13  manufacturerNumber   2482 non-null   object
#  14  name                 10000 non-null  object
# ...

# %%
# seleccion de datos

df=df[['brand', 'colors', 'sizes', 'prices.amountMax', 'imageURLs', 'ean']]

df.head()
# Out:
#          brand                          colors  \
# 0  Naturalizer  Silver,Cream Watercolor Floral
# 1     MUK LUKS                            Grey
# 2     MUK LUKS                            Grey
# 3     MUK LUKS                           Black
# 4     MUK LUKS                            Grey
#
#                                                sizes  prices.amountMax  \
# 0  6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...             55.99
# 1                                         10,7,6,9,8             47.00
# 2                                         10,7,6,9,8             35.25
# 3                                         10,7,6,9,8             24.75
# 4                                         10,7,6,9,8             33.00
#
#                                            imageURLs           ean
# 0  https://i5.walmartimages.com/asr/861ca6cf-fa55...           NaN
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# ...

# %%
df['imageURLs'][0]
# Out:
# 'https://i5.walmartimages.com/asr/861ca6cf-fa55-4a48-904d-b764d7c00f0c_1.1a2bb39923e1486d05bdafe37ad832e3.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/efe9ba1e-daed-4534-9e2e-11804bbb30f1_1.62e3e7f0268f641323a245d5caebdd6d.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/0c717815-228e-4c9b-a8fc-d033576461c9_1.f08402e0a5165746e133ddeb589c73e0.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/f46703c8-2cdb-4bf2-a3ea-819f24aab134_1.df725b76ca0112d64bdf566ad97760a9.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/f652f354-a1fb-47ac-b507-7f97eb216b14_1.39e78b87e2328421803115869ee8b950.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,http://ak1.ostkcdn.com/images/products/84/146/P16141204.jpg,http://s1.shoes.com/images/br021/womens-naturalizer-danya-soft-silver-crosshatch-shiny-377672_366_tp.jpg,http://s3.shoes.com/images/br021/womens-naturalizer-danya-soft-silver-crosshatch-s
# ...

# %%
# quita nan

df=df.dropna().reset_index(drop=True)

df.head()
# Out:
#        brand       colors       sizes  prices.amountMax  \
# 0   MUK LUKS         Grey  10,7,6,9,8             47.00
# 1   MUK LUKS         Grey  10,7,6,9,8             35.25
# 2   MUK LUKS        Black  10,7,6,9,8             24.75
# 3   MUK LUKS         Grey  10,7,6,9,8             33.00
# 4  Soft Ones  Brown Tweed  5,6.5,9,11             14.00
#
#                                            imageURLs           ean
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 2  https://i5.walmartimages.com/asr/950d38a5-0113...  3.397705e+10
# 3  https://i5.walmartimages.com/asr/5e137bc3-c900...  3.397705e+10
# 4  https://i5.walmartimages.com/asr/7b979ba6-fa0a...  3.397705e+10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664 entries, 0 to 663
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             664 non-null    object
#  1   colors            664 non-null    object
#  2   sizes             664 non-null    object
#  3   prices.amountMax  664 non-null    float64
#  4   imageURLs         664 non-null    object
#  5   ean               664 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 31.2+ KB

# %%
df.sizes=df.sizes.apply(lambda x: x.split(','))
df.colors=df.colors.apply(lambda x: x.split(','))

df.head()
# Out:
#        brand         colors             sizes  prices.amountMax  \
# 0   MUK LUKS         [Grey]  [10, 7, 6, 9, 8]             47.00
# 1   MUK LUKS         [Grey]  [10, 7, 6, 9, 8]             35.25
# 2   MUK LUKS        [Black]  [10, 7, 6, 9, 8]             24.75
# 3   MUK LUKS         [Grey]  [10, 7, 6, 9, 8]             33.00
# 4  Soft Ones  [Brown Tweed]   [5, 6.5, 9, 11]             14.00
#
#                                            imageURLs           ean
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 2  https://i5.walmartimages.com/asr/950d38a5-0113...  3.397705e+10
# 3  https://i5.walmartimages.com/asr/5e137bc3-c900...  3.397705e+10
# 4  https://i5.walmartimages.com/asr/7b979ba6-fa0a...  3.397705e+10

# %%
# un registro por talla y color

df=df.explode('sizes').reset_index(drop=True)
df=df.explode('colors').reset_index(drop=True)

df.head()
# Out:
#       brand colors sizes  prices.amountMax  \
# 0  MUK LUKS   Grey    10              47.0
# 1  MUK LUKS   Grey     7              47.0
# 2  MUK LUKS   Grey     6              47.0
# 3  MUK LUKS   Grey     9              47.0
# 4  MUK LUKS   Grey     8              47.0
#
#                                            imageURLs           ean
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  3.397705e+10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             41188 non-null  object
#  1   colors            41188 non-null  object
#  2   sizes             41188 non-null  object
#  3   prices.amountMax  41188 non-null  float64
#  4   imageURLs         41188 non-null  object
#  5   ean               41188 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 1.9+ MB

# %%
codigo=pd.read_csv('../data/upc_corpus.csv')
codigo=codigo.dropna().reset_index(drop=True)

codigo.head()
# Out:
# /Users/iudh/opt/anaconda3/envs/clase/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3172: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             ean                                               name
# 0  725177540363  Belle and The Yank 1/4" - 20 TPI x 90mm Hex Dr...
# 1  725177540370  Belle and The Yank 1/4" - 20 TPI x 120mm Hex D...
# 2  797776092321       Eazel Wines 750ml Red Wine Eazel Shiraz 2014
# 3  701197194311  IsyLei lilla IsyLei All-In-One, lilla - Cono L...
# 4  797776110773                    MsConscious 370g Skinny Granola

# %%
codigo.shape
# Out:
# (1045885, 2)

# %%
df.ean=codigo.ean

df.tail()
# Out:
#              brand   colors    sizes  prices.amountMax  \
# 41183  easy street   Yellow  12 WIDE             54.99
# 41184  easy street     Navy  12 WIDE             54.99
# 41185  easy street  Natural  12 WIDE             54.99
# 41186  easy street    Coral  12 WIDE             54.99
# 41187  easy street   Pewter  12 WIDE             54.99
#
#                                                imageURLs           ean
# 41183  https://media.kohlsimg.com/is/image/kohls/2794...  998929898887
# 41184  https://media.kohlsimg.com/is/image/kohls/2794...  999982603302
# 41185  https://media.kohlsimg.com/is/image/kohls/2794...  999982603401
# 41186  https://media.kohlsimg.com/is/image/kohls/2794...  999982603609
# 41187  https://media.kohlsimg.com/is/image/kohls/2794...  999994448700

# %%
# renombrar

df.columns=['brand', 'color', 'size', 'price', 'image', 'ean']

df.head()
# Out:
#       brand color size  price  \
# 0  MUK LUKS  Grey   10   47.0
# 1  MUK LUKS  Grey    7   47.0
# 2  MUK LUKS  Grey    6   47.0
# 3  MUK LUKS  Grey    9   47.0
# 4  MUK LUKS  Grey    8   47.0
#
#                                                image           ean
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773

# %%
# id

df['id']=[i for i in range(len(df))]

df.head()
# Out:
#       brand color size  price  \
# 0  MUK LUKS  Grey   10   47.0
# 1  MUK LUKS  Grey    7   47.0
# 2  MUK LUKS  Grey    6   47.0
# 3  MUK LUKS  Grey    9   47.0
# 4  MUK LUKS  Grey    8   47.0
#
#                                                image           ean  id
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363   0
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370   1
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321   2
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311   3
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773   4

# %% [markdown]
# ### MySQL Connector

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn

# %%
# crea una base de datos

crea_db=conn.connect(host='localhost', user='root', passwd='password') # se conecta con el servidor de sql

cursor=crea_db.cursor()  # la conexion en si misma

cursor.execute('drop database if exists productos')
cursor.execute('create database productos')

# %%
# check

cursor.execute('show databases;')

for x in cursor:
    print(x)
# Out:
# ('apps',)
# ('bank',)
# ('information_schema',)
# ('mydb',)
# ('mysql',)
# ('performance_schema',)
# ('productos',)
# ('prueba_etl',)
# ('publications',)
# ('sakila',)
# ('sqlmurder',)
# ('sys',)
# ('telcom',)

# %%
# conecta a sql

db=conn.connect(host='localhost', user='root', passwd='password', database='productos') # directo a la db

cursor=db.cursor()  # la conexion en si misma

# %%
# crea una tabla

cursor.execute('drop table if exists zapatos')


tabla='''

        create table zapatos(
            
            id int, 
            brand varchar(50),
            color varchar(50),
            size varchar(50),
            price float,
            image varchar(10000),
            ean varchar(50)
        );

'''

cursor.execute(tabla)

# %%
# check

cursor.execute('show tables;')

for x in cursor:
    print(x)
# Out:
# ('zapatos',)

# %% [markdown]
# ### Inserta datos

# %%
# insert query, insert into nombre_tabla (columnas, nombre...) values 1,2,3..;


for i in df.index:
    
    insert_query='insert into {} ({}) values {};'.format('zapatos', 
                                                         ','.join(df.columns), 
                                                         tuple(df.iloc[i].values))
    
    cursor.execute(insert_query)

db.commit()  # esto machaca la db, aseguramos el guardado

# %%
df.head()
# Out:
#       brand color size  price  \
# 0  MUK LUKS  Grey   10   47.0
# 1  MUK LUKS  Grey    7   47.0
# 2  MUK LUKS  Grey    6   47.0
# 3  MUK LUKS  Grey    9   47.0
# 4  MUK LUKS  Grey    8   47.0
#
#                                                image           ean  id
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363   0
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370   1
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321   2
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311   3
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773   4

# %%
# insert query, insert into nombre_tabla (columnas, nombre...) values 1,2,3..;

tabla='zapatos'

columnas=','.join(df.columns)  # devuelve una string con los nombres separados por comas


for i in df.index:  # para cada fila del df....
    
    datos=tuple(df.iloc[i].values) # convierte los datos a tupla...
    
    insert_query=f'insert into {tabla} ({columnas}) values {datos};'  # string de python como query de sql 
    
    cursor.execute(insert_query) # darle al rayo

db.commit()  # esto machaca la db, aseguramos el guardado

# %%
# check

cursor.execute('select * from zapatos where price>47 limit 1')

for x in cursor:
    print(x)
# Out:
# (122, 'MUK LUKS', 'Navy', '10', 59.0, 'https://i5.walmartimages.com/asr/33997517-2082-4c2e-aa1d-411f920fe7f8_1.12bd1109e37eb86925972396fdd39962.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/1e327bdf-8bc9-47c6-9fd2-68b3381ef296_1.9f1aa88c9025f897b39079239c05b12a.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/e4f650f1-db4c-49b9-89b5-8fa9ba9d669c_1.f4ef708b274294f98bf00668dea3ecb9.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/df61fddb-b52e-4979-8661-542e994f83dc_1.60e82099e87e82679615e6d378db9654.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/9531a4dd-b700-463e-afdd-f0e521de5d9a_1.83df969be86e4d7a74638d64db3aafe4.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/34b890a0-c838-4f37-a822-25732567814e_1.3674e9bd1ec7e0a9e53608c4ef26de19.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF', '797776236541')

# %% [markdown]
# ### SqlAlchemy

# %%
# !pip install SQLAlchemy  # libreria

# %%
# !pip install pymysql   # driver

# %%
from sqlalchemy import create_engine    # motor de conexion == cursor

# %%
# lenguaje+driver://usuario:password@servidor:puerto/database  # string de conexion

str_conn='mysql+pymysql://root:password@localhost:3306/apps'

motor=create_engine(str_conn)

# %%
datos=pd.read_csv('../data/apple_store.csv')

datos.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#    price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0   3.99             21292                26          4.0              4.5
# 1   0.00            161065                26          4.0              3.5
# 2   0.00            188583              2822          3.5              4.5
# 3   0.00            262241               649          4.0              4.5
# 4   0.00            985920              5320          4.5              5.0
#
#     prime_genre
# 0         Games
# 1  Productivity
# ...

# %%
datos.to_sql(name='Ratings', con=motor, if_exists='append', index=False) # motor con sqlalchemy

# %%
datos2=pd.read_sql('select * from Ratings', motor)

datos2.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#    price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0   3.99             21292                26          4.0              4.5
# 1   0.00            161065                26          4.0              3.5
# 2   0.00            188583              2822          3.5              4.5
# 3   0.00            262241               649          4.0              4.5
# 4   0.00            985920              5320          4.5              5.0
#
#     prime_genre
# 0         Games
# 1  Productivity
# ...

# %% [markdown]
# ### SQL - Pandas

# %%
# lectura de sql a través de pandas

df_sql=pd.read_sql('select * from zapatos', con=db)

df_sql.head()
# Out:
#    id     brand color size  price  \
# 0   0  MUK LUKS  Grey   10   47.0
# 1   1  MUK LUKS  Grey    7   47.0
# 2   2  MUK LUKS  Grey    6   47.0
# 3   3  MUK LUKS  Grey    9   47.0
# 4   4  MUK LUKS  Grey    8   47.0
#
#                                                image           ean
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773

# %%
# desde connector

cursor.execute('select * from zapatos')

data=cursor.fetchall()

# %%
df=pd.DataFrame(data, columns=cursor.column_names)

df.head()
# Out:
#    id     brand color size  price  \
# 0   0  MUK LUKS  Grey   10   47.0
# 1   1  MUK LUKS  Grey    7   47.0
# 2   2  MUK LUKS  Grey    6   47.0
# 3   3  MUK LUKS  Grey    9   47.0
# 4   4  MUK LUKS  Grey    8   47.0
#
#                                                image           ean
# 0  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540363
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...  725177540370
# 2  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776092321
# 3  https://i5.walmartimages.com/asr/421de5d5-3a74...  701197194311
# 4  https://i5.walmartimages.com/asr/421de5d5-3a74...  797776110773

# %%
# otra vez con sqlalchemy, el motor


datos=pd.read_sql('''

            select prime_genre, sum(rating_count_tot) as total_rating, avg(user_rating) as avg_rat
            from Ratings
            where price=0
            group by prime_genre
            order by total_rating desc
            limit 10;''',
                 motor)

datos.head()
# Out:
#          prime_genre  total_rating   avg_rat
# 0              Games   256278138.0  3.528578
# 1  Social Networking    45541092.0  2.996503
# 2      Photo & Video    27304392.0  3.793413
# 3              Music    22705776.0  3.940299
# 4      Entertainment    21689214.0  3.148204

# %%
str_conn='mysql+pymysql://root:password@localhost:3306/publications'

motor=create_engine(str_conn)

# %%
query='''
        select group_concat(t.title) as titles,
        t.year
        from (select title, year(max(pubdate)) as 'year',
        count(titleauthor.title_id) as num_titles,
        group_concat(concat(authors.au_fname, ' ', authors.au_lname)) as authors
        from titles
        left join titleauthor
        on titles.title_id=titleauthor.title_id
        left join authors
        on authors.au_id=titleauthor.au_id
        group by titles.title
        order by num_titles desc) as t
        group by t.year;

'''

# %%
df=pd.read_sql(query, motor)

df.head()
# Out:
#                                               titles  year
# 0  Sushi, Anyone?,Computer Phobic AND Non-Phobic ...  1991
# 1                          Secrets of Silicon Valley  1994
# 2   Net Etiquette,The Psychology of Computer Cooking  2014

# %%
# %%time

pd.read_sql('select * from publications.employee;', motor)['job_id'].sum()
# Out:
# CPU times: user 4.04 ms, sys: 1.17 ms, total: 5.21 ms
# Wall time: 5.62 ms
# 365

# %%
# %%time

pd.read_sql('select sum(job_id) as j from publications.employee', motor)['j'][0]
# Out:
# CPU times: user 1.91 ms, sys: 725 µs, total: 2.64 ms
# Wall time: 2.95 ms
# 365.0

# %%
pd.read_sql('show tables;', motor)
# Out:
#    Tables_in_publications
# 0                 authors
# 1               discounts
# 2                employee
# 3                    jobs
# 4                pub_info
# 5              publishers
# 6                roysched
# 7                   sales
# 8                  stores
# 9             titleauthor
# 10                 titles
