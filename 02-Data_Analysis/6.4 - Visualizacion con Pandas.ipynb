# %% [markdown]
# # 6.4 - Visualización con Pandas
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd
import numpy as np

import pylab as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# **Line plot**

# %%
df=pd.Series(np.random.randn(1000), 
             index=pd.date_range('1/1/2000', periods=1000))

display(df.head())

df=df.cumsum()

df.plot();
# Out:
# 2000-01-01    1.158266
# 2000-01-02    1.076291
# 2000-01-03    0.941367
# 2000-01-04   -0.271939
# 2000-01-05    0.153907
# Freq: D, dtype: float64

# %%
df=pd.DataFrame(np.random.randn(1000, 4), 
             index=pd.date_range('1/1/2000', periods=1000),
             columns=['a', 'b', 'c', 'd'])

df['letras']=['hola' for i in range(1000)]

display(df.head())

df=df.cumsum()

df.plot();
# Out:
#                    a         b         c         d letras
# 2000-01-01 -0.147692 -0.219737 -0.259685  0.894494   hola
# 2000-01-02  0.358012 -0.416756 -1.288849  1.342282   hola
# 2000-01-03  1.221365 -0.791025  0.242890 -1.083849   hola
# 2000-01-04 -0.776746 -2.254508  0.330712  0.424164   hola
# 2000-01-05 -1.048275  0.098436 -0.748063  0.358544   hola

# %%
df.a.plot();

# %%
df.plot(x='a', y='b');

# %% [markdown]
# **Bar plot**

# %%
df=df._get_numeric_data()

df.iloc[5].plot(kind='bar');

# %%
df.iloc[5].plot(kind='bar')

plt.axhline(-3, color='k');

# %%
df.index=[i for i in range(1000)]

# %%
df.plot.bar();

# %%
df.plot.bar(stacked=True);

# %%
df.plot.barh(stacked=True);

# %% [markdown]
# **Histograma**

# %%
df.plot.hist();

# %%
df.plot.hist(stacked=True, bins=30);

# %%
#help(df.plot())

# %%
df.a.plot.hist(orientation='horizontal');

# %%
df.a.plot.hist(orientation='horizontal', cumulative=True);

# %% [markdown]
# **Box plots**

# %%
df.b.plot.box();

# %%
df.boxplot();

# %%
color={'boxes': 'DarkGreen',
       'whiskers': 'DarkOrange',
       'medians': 'DarkBlue',
       'caps': 'Gray'}

df.plot.box(color=color,
            sym='r+',
            vert=False
           );

# %% [markdown]
# **Area plot**

# %%
df=df.apply(lambda x: abs(x))

df.plot.area();

# %%
df.plot.area(stacked=False);

# %% [markdown]
# **Scatter plot**

# %%
df.plot.scatter(x='c', y='a');

# %%
ax_=df.plot.scatter(x='c', y='a')

df.plot.scatter(x='b', y='d', color='DarkGreen', ax=ax_);

# %%
df.plot.scatter(x='c', y='a', c='b');

# %%
df.plot.scatter(x='c', y='a', c='d', s=5);

# %%
df.plot.scatter(x='c', y='a', c='d', s='b');

# %% [markdown]
# **Hexagonal bin plot**

# %% [markdown]
# **Pie plot**

# %% [markdown]
# **Scatter matrix plot**

# %% [markdown]
# **curvas de Andrews**

# %% [markdown]
# **coordenadas paralelas**

# %% [markdown]
# # Extensiones para Jupyter

# %% [markdown]
# ### Lux
#
# https://github.com/lux-org/lux-widget
#
# https://stackoverflow.com/questions/68046925/how-can-i-make-the-lux-package-work-in-python

# %% [markdown]
# ### QGrid
#
# https://github.com/quantopian/qgrid

# %% [markdown]
# ### iTables
#
# https://github.com/mwouts/itables

# %% [markdown]
# ### Jupyter DataTables
#
# https://github.com/CermakM/jupyter-datatables

# %% [markdown]
# ### ipyvolume
#
# https://github.com/maartenbreddels/ipyvolume

# %% [markdown]
# ### bqplot
#
# https://github.com/bqplot/bqplot

# %% [markdown]
# ### Atoti
#
# https://docs.atoti.io/latest/tutorial/tutorial.html
